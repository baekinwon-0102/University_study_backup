# %%
# Python3 샘플코드
import requests

# 공공데이터 포텔에서 발급받은 서비스 키
SERVICE_KEY = '2d664b77231d79af0e90ebb2bed456dfb5242491138aea9aad065fddc912078f'
# 호출 기준 날짜와 시간
base_date = '20260518'
base_time = '1400'
# 특정지역 좌표 (경기과학기술대학교, 시흥시 정왕동)
FIXED_NX = 56
FIXED_NY = 122
url = 'http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getUltraSrtNcst'
params ={'serviceKey' : SERVICE_KEY, 'pageNo' : '1', 'numOfRows' : '1000', 'dataType' : 'JSON', 'base_date' : base_date, 'base_time' : base_time, 'nx' : FIXED_NX, 'ny' : FIXED_NY }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"baseDate":"20260518","baseTime":"1400","category":"PTY","nx":56,"ny":122,"obsrValue":"0"},{"baseDate":"20260518","baseTime":"1400","category":"REH","nx":56,"ny":122,"obsrValue":"26"},{"baseDate":"20260518","baseTime":"1400","category":"RN1","nx":56,"ny":122,"obsrValue":"0"},{"baseDate":"20260518","baseTime":"1400","category":"T1H","nx":56,"ny":122,"obsrValue":"27.2"},{"baseDate":"20260518","baseTime":"1400","category":"UUU","nx":56,"ny":122,"obsrValue":"2.5"},{"baseDate":"20260518","baseTime":"1400","category":"VEC","nx":56,"ny":122,"obsrValue":"227"},{"baseDate":"20260518","baseTime":"1400","category":"VVV","nx":56,"ny":122,"obsrValue":"2.3"},{"baseDate":"20260518","baseTime":"1400","category":"WSD","nx":56,"ny":122,"obsrValue":"3.3"}]},"pageNo":1,"numOfRows":1000,"totalCount":8}}}'

# %% [raw]
# b'{"response":
#     {"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},
#     "body":{"dataType":"JSON",
#     "items":{
#         "item":[{"baseDate":"20260518","baseTime":"1400","category":"PTY","nx":56,"ny":122,"obsrValue":"0"},{"baseDate":"20260518","baseTime":"1400","category":"REH","nx":56,"ny":122,"obsrValue":"26"},{"baseDate":"20260518","baseTime":"1400","category":"RN1","nx":56,"ny":122,"obsrValue":"0"},{"baseDate":"20260518","baseTime":"1400","category":"T1H","nx":56,"ny":122,"obsrValue":"27.2"},{"baseDate":"20260518","baseTime":"1400","category":"UUU","nx":56,"ny":122,"obsrValue":"2.5"},{"baseDate":"20260518","baseTime":"1400","category":"VEC","nx":56,"ny":122,"obsrValue":"227"},{"baseDate":"20260518","baseTime":"1400","category":"VVV","nx":56,"ny":122,"obsrValue":"2.3"},{"baseDate":"20260518","baseTime":"1400","category":"WSD","nx":56,"ny":122,"obsrValue":"3.3"}]},"pageNo":1,"numOfRows":1000,"totalCount":8}}}'
