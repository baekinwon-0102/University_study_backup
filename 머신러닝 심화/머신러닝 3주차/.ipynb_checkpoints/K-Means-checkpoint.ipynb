# %%
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

from sklearn import datasets

iris = datasets.load_iris()

x = iris.data[:,2:]

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusteimport warnings
warnings.simplefilter(action='ignore', category=UserWarning)

from sklearn import datasets

iris = datasets.load_iris()

x = iris.data[:,2:]

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2,random_state=21) # n_clusters는 k(중심점)의 개수
kmeans.fit(x)

y_pred = kmeans.labels_

import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(16,8))

y= iris.target
axes[0].scatter(x[:,0],x[:,1],c = y, cmap = 'gist_rainbow',edgecolor='k',s=150)
axes[0].set_title('Actual',fontsize=18)

axes[1].scatter(x[:,0],x[:,1],c=y_pred,cmap='prism',edgecolor='k',s=150)
axes[1].set_title('Predicted',fontsize=18)s=2,random_state=21) # n_clusters는 k(중심점)의 개수
kmeans.fit(x)

y_pred = kmeans.labels_

import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(16,8))

y= iris.target
axes[0].scatter(x[:,0],x[:,1],c = y, cmap = 'gist_rainbow',edgecolor='k',s=150)
axes[0].set_title('Actual',fontsize=18)

axes[1].scatter(x[:,0],x[:,1],c=y_pred,cmap='prism',edgecolor='k',s=150)
axes[1].set_title('Predicted',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Predicted')

# %%
iris = datasets.load_iris()

x = iris.data[:,2:]

kmeans = KMeans(n_clusters=3,random_state=21) # n_clusters는 k(중심점)의 개수
kmeans.fit(x)

y_pred = kmeans.labels_

fig, axes = plt.subplots(1, 2, figsize=(16,8))

y= iris.target
axes[0].scatter(x[:,0],x[:,1],c = y, cmap = 'gist_rainbow',edgecolor='k',s=150)
axes[0].set_title('Actual',fontsize=18)

axes[1].scatter(x[:,0],x[:,1],c=y_pred,cmap='prism',edgecolor='k',s=150)
axes[1].set_title('Predicted',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Predicted')

# %%
iris = datasets.load_iris()

x = iris.data[:,1:3]

kmeans = KMeans(n_clusters=3,random_state=21) # n_clusters는 k(중심점)의 개수
kmeans.fit(x)

y_pred = kmeans.labels_

fig, axes = plt.subplots(1, 2, figsize=(16,8))

y= iris.target
axes[0].scatter(x[:,0],x[:,1],c = y, cmap = 'gist_rainbow',edgecolor='k',s=150)
axes[0].set_title('Actual',fontsize=18)

axes[1].scatter(x[:,0],x[:,1],c=y_pred,cmap='prism',edgecolor='k',s=150)
axes[1].set_title('Predicted',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Predicted')

# %%
iris = datasets.load_iris()

x = iris.data[:,:3] # 3차원 데이터

kmeans = KMeans(n_clusters=3,random_state=21) # n_clusters는 k(중심점)의 개수
kmeans.fit(x)

y_pred = kmeans.labels_

fig, axes = plt.subplots(1, 2, figsize=(16,8))

y= iris.target
axes[0].scatter(x[:,0],x[:,1],c = y, cmap = 'gist_rainbow',edgecolor='k',s=150)
axes[0].set_title('Actual',fontsize=18)

axes[1].scatter(x[:,0],x[:,1],c=y_pred,cmap='prism',edgecolor='k',s=150)
axes[1].set_title('Predicted',fontsize=18)
# 결과값 보면 2차원과 달리 데이터가 겹쳐 보일 수 있음
# Out:
# Text(0.5, 1.0, 'Predicted')
